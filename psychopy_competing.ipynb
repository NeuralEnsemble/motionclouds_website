# %% [markdown]
# # Analysis of a discrimination experiment

# %% [markdown]
# In the ``psychopy_competition.py`` script, we implemented an experiment to test whether one could discriminate the dominating motionin a sum of two motion cloudsin opposite directions.

# %% [markdown]
# Herein, we analyse the data that was collected over different sessions and try to draw some conclusions.

# %% [markdown]
# ## The experiment

# %%
#%pycat psychopy_competing.py

# %% [markdown]
# ## Analysis, version 1

# %% [markdown]
# In a first version of the experiment, we only stored the results in a numpy file:

# %%
# !ls  data/*npy
# Out:
# data/competing_v1_bruno_Dec_14_1210.npy  data/competing_v1_lup_Dec_14_1201.npy	   data/discriminating_lup_Jan_23_1401.npy  data/discriminating_lup_Jan_24_0919.npy
# data/competing_v1_lup_Dec_12_1003.npy	 data/competing_v1_meduz_Dec_14_1204.npy   data/discriminating_lup_Jan_23_1735.npy  data/discriminating_lup_Jan_24_0931.npy
# data/competing_v1_lup_Dec_12_1013.npy	 data/discriminating_john_Jan_23_1515.npy  data/discriminating_lup_Jan_24_0914.npy  data/discriminating_lup_Jan_24_0937.npy

# %%
import glob
fig = plt.figure()
ax = fig.add_subplot(111)
for fn in glob.glob('data/competing_v1_*npy'):
    results = np.load(fn)
    print fn, results.shape
    ax.scatter(results[1, :], results[0, :])
ax.axis([0., 1., -1.1, 1.1])
ax.set_xlabel('contrast')
ax.set_ylabel('perceived direction')
# Out:
# data/competing_v1_bruno_Dec_14_1210.npy (2, 50)
# data/competing_v1_lup_Dec_12_1003.npy (2, 50)
# data/competing_v1_lup_Dec_12_1013.npy (2, 50)
# data/competing_v1_lup_Dec_14_1201.npy (2, 10)
# data/competing_v1_meduz_Dec_14_1204.npy (2, 50)

# %%
alpha = .3
fig = plt.figure(figsize=(12,5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
for fn in glob.glob('data/competing_v1_*npy'):
    results = np.load(fn)
    ax1.scatter(results[1, results[1, :]<.5], 1.*(results[0, results[1, :]<.5]==-1), c='r', alpha=alpha)
    ax1.scatter(results[1, results[1, :]>.5], 1.*(results[0, results[1, :]>.5]==1), c='b', alpha=alpha)
    ax2.scatter(results[1, results[1, :]<.5], 1.*(results[0, results[1, :]<.5]==1), c='b', alpha=alpha, marker='x')
    ax2.scatter(results[1, results[1, :]>.5], 1.*(results[0, results[1, :]>.5]==-1), c='r', alpha=alpha, marker='x')
for ax in [ax1, ax2]:
    ax.axis([0., 1., -.1, 1.1])
    _ = ax.set_xlabel('contrast')
_ = ax1.set_ylabel('correct')
_ = ax2.set_ylabel('incorrect')

# %% [markdown]
# (note the subplots are equivalent up to a flip)

# %% [markdown]
# One could not fit psychometric curves for this 2AFC. See for instance https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3110332/

# %%
n_hist = 100
fig = plt.figure()
ax = fig.add_subplot(111)
for fn in glob.glob('data/competing_v1_*npy'):
    results = np.load(fn)
    hist, bins = np.histogram(results[1, results[0, :]==1], bins=np.linspace(0, 1, n_hist), normed=True)
    plt.plot(bins[:-1], np.cumsum(hist)/hist.sum())
    hist, bins = np.histogram(results[1, results[0, :]==-1], bins=np.linspace(0, 1, n_hist), normed=True)
    plt.plot(bins[:-1], np.cumsum(hist)/hist.sum(), '--')
#ax.axis([0., 1., 0., 1.])
ax.set_xlabel('contrast')

# %% [markdown]
# let's explore another way:

# %%
import pypsignifit as psi

# %% [markdown]
# data :
# an array or a list of lists containing stimulus intensities in the first column, number of correct responses (nAFC) or number of YES- responses in the second column, and number of trials in the third column. Each row should correspond to one experimental block. In addition, the sequence of the rows is taken as the sequence of data aquisition. Alternatively, the relative frequencies of correct responses resp YES responses can be given.

# %%
stimulus_intensities, percent_correct = np.array([]), np.array([])
#data = []
for fn in glob.glob('data/competing_v1_*npy'):
#    data_ = []
    results = np.load(fn)
    #data_single_session = np.concatenate((results[1, results[1, :]<.5], 1.*(results[0, results[1, :]<.5]==-1), np.array([num_observations])))
    #data_single_sessions = np.vstack((data_single_sessions, data_single_session))
    stimulus_intensities = np.hstack((stimulus_intensities, results[1, results[1, :]<.5]))
    percent_correct = np.hstack((percent_correct, 1.*(results[0, results[1, :]<.5]==-1)))
#    data_.append(results[1, results[1, :]<.5])
#    data_.append((percent_correct, 1.*(results[0, results[1, :]<.5]==-1)))
#    data.append(data_)
    stimulus_intensities = np.hstack((stimulus_intensities, results[1, results[1, :]>.5]))
    percent_correct = np.hstack((percent_correct, 1.*(results[0, results[1, :]>.5]==1)))
    print stimulus_intensities.shape, percent_correct.shape

num_observations = len(stimulus_intensities)
print num_observations
#data_single_sessions = np.c_[stimulus_intensities, percent_correct, np.array([num_observations])]
data_single_sessions = [stimulus_intensities, percent_correct, np.array([2]*len(stimulus_intensities))]
print data_single_sessions[0].shape, data_single_sessions[1].shape, data_single_sessions[2].shape
# Out:
# (50,) (50,)
# (100,) (100,)
# (150,) (150,)
# (160,) (160,)
# (210,) (210,)
# 210
# (210,) (210,) (210,)

# %%
nafc = 2
constraints = ( 'unconstrained', 'unconstrained',"Uniform(0,0.1)")
B_single_sessions = psi.BootstrapInference ( data_single_sessions, priors=constraints, nafc=nafc )
print B.estimate, B.deviance, B.getThres(), B.getCI(1)
# Out:
# [ 3.80588742  1.09307764  0.00935752] 2.51609892172 3.80588741791 [ 2.79005677  4.57052507]

# %%
psi.psignidata?
