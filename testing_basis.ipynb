# %% [markdown]
# # Motion Clouds: raw principles

# %%
def show_video(filename):
    from IPython.display import HTML
    from base64 import b64encode
    video = open(mc.figpath + filename + mc.vext, "rb").read()
    video_encoded = b64encode(video)
    video_tag = '<video controls  autoplay="autoplay" loop="loop" width=350px src="data:video/x-m4v;base64,{0}">'.format(video_encoded)
    HTML(data=video_tag)

# %% [markdown]
# ## Introduction

# %% [markdown]
# Motion Clouds are synthesized textures which aim at having similar characteristics as natural images but with controlled parameters. There are many ways to achieve these results and this notebook aims at showing that different procedures from different communities (neurioscience, modelling, computer vision, ...) may produce similar results.

# %% [markdown]
# ## Using mixtures of images

# %% [markdown]
# ## Using Fourier ("official Motion Clouds")

# %%
import MotionClouds as mc

fx, fy, ft = mc.get_grids(mc.N_X, mc.N_Y, mc.N_frame)

# %% [markdown]
# ## Using ARMA processes

# %%
import scipy.misc
lena = scipy.misc.lena() * 1.
lena -= lena.mean()
lena /= lena.std()
print lena.shape
# Out:
# (512, 512)

# %%
imshow(lena, cmap=cm.gray)

# %%
def noise(image=lena):
    for axis in [0, 1]:
        image = np.roll(image, np.random.randint(image.shape[axis]), axis=axis)
    return image

# %%
imshow(noise(), cmap=cm.gray)

# %%
imshow(noise(), cmap=cm.gray)

# %% [markdown]
# Now, we define the ARMA process as an averaging process with a certain time constant $\tau=30.$ (in frames).

# %%
def ARMA(image, tau=30.):
    image = (1 - 1/tau)* image + noise()
    return image

# %% [markdown]
# initializing

# %%
image = ARMA(lena)
imshow(image, cmap=cm.gray)

# %%
for _ in range(1000): image = ARMA(image)
imshow(image, cmap=cm.gray)

# %%
for _ in range(1000): image = ARMA(image)
imshow(image, cmap=cm.gray)

# %%
for _ in range(1000): image = ARMA(image)
imshow(image, cmap=cm.gray)

# %%
N_frame = 128
z = np.zeros((lena.shape[0], lena.shape[1], N_frame))
z[:, :, 0] = image
for i_frame in range(1, N_frame): z[:, :, i_frame] = ARMA(z[:, :, i_frame-1])        
mc.anim_save(z, filename='arma')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-245623727d69> in <module>()
#       3 z[:, :, 0] = image
#       4 for i_frame in range(1, N_frame): z[:, :, i_frame] = ARMA(z[:, :, i_frame-1])
# ----> 5 mc.anim_save(z, filename='arma')
#       6 show_video(filename='arma')
#
# /Users/lolo/science/MotionClouds/MotionClouds.pyc in anim_save(z, filename, display, flip, vext, centered, fps)
#     443     if vext == '.mp4': # specially tuned for iPhone/iPod http://www.dudek.org/blog/82
#     444         # 1) create temporary frames
# --> 445         tmpdir, files = make_frames(z)
#     446         # 2) convert frames to movie
#     447         options = '-vcodec libx264 -y '
#
# /Users/lolo/science/MotionClouds/MotionClouds.pyc in make_frames(z)
#     412             if flip: image = np.flipud(image)
#     413             toimage(image, high=255, low=0, cmin=0., cmax=1., pal=None,
# --> 414                     mode=None, channel_axis=None).save(fname)
#     415             files.append(fname)
#     416             if PROGRESS: pbar.update(frame)
#
# /usr/local/lib/python2.7/site-packages/PIL/Image.pyc in save(self, fp, format, **params)
#
# KeyError: '.png'
# Saving sequence arma.mp4
# calculating   0% |                                             | ETA:  --:--:--

# %%
show_video(filename='arma')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-59-2ce6e30e36d3> in <module>()
# ----> 1 show_video(filename='arma')
#
# <ipython-input-43-1ed8576a5d93> in show_video(filename)
#       2     from IPython.display import HTML
#       3     from base64 import b64encode
# ----> 4     video = open(mc.figpath + filename + mc.vext, "rb").read()
#       5     video_encoded = b64encode(video)
#       6     video_tag = '<video controls  autoplay="autoplay" loop="loop" width=350px src="data:video/x-m4v;base64,{0}">'.format(video_encoded)
#
# IOError: [Errno 2] No such file or directory: 'results/arma.mp4'
